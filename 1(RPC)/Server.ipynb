# %%
from xmlrpc.server import SimpleXMLRPCServer

def factorial(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    
    return str(result)   # Convert to string

server = SimpleXMLRPCServer(("127.0.0.1", 9000))

server.register_function(factorial, "factorial")

print("Server running on port 9000")

server.serve_forever()
# Out:
# Server running on port 9000
# 127.0.0.1 - - [07/May/2026 19:00:46] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/May/2026 19:00:50] "POST / HTTP/1.1" 200 -
